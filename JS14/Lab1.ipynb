# %% [markdown]
# # Lab 1

# %% [markdown]
# ### Step 1 - Import Libraries

# %%
# %pip install tensorflow
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Step 2 - Data Preprocessing

# %% [markdown]
# In this stage we will perform a number of manipulations on the images used. The manipulations include pixel value normalization, shear correction, zoom augmentation, and flipping.

# %% [markdown]
# Step 2.1 - Training Data Preprocessing

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# Step 2.2 - Testing Data Preprocessing

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ### Step 3 - Construction of the CNN Model

# %% [markdown]
# Step 3.1 - CNN Model Initialization

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# Step 3.2 - Creation of Convolutional Layer 1

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))
# Out:
# c:\Users\Sherly\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Step 3.3 - Creation of Pooling Layer 1

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# Step 3.4 - Creation of Convolutional Layer 2 and Pooling 2

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# Step 3.5 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# Step 3.6 - Fully Connected Layer 1 (Input)

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# Step 3.7 - Fully Connected Layer 2 (Output)

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# Step 3.8 - Compile the CNN Model

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# Usage loss function: binary crossentropy because we are performing classification across only two classes, namely cat and dog.

# %% [markdown]
# ### Step 4 - Fit the CNN

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 207s 818ms/step - accuracy: 0.5815 - loss: 0.6721 - val_accuracy: 0.6495 - val_loss: 0.6262
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 54s 218ms/step - accuracy: 0.6669 - loss: 0.6083 - val_accuracy: 0.6740 - val_loss: 0.6035
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 61s 243ms/step - accuracy: 0.7066 - loss: 0.5651 - val_accuracy: 0.7440 - val_loss: 0.5338
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 58s 232ms/step - accuracy: 0.7305 - loss: 0.5344 - val_accuracy: 0.7415 - val_loss: 0.5320
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 57s 227ms/step - accuracy: 0.7515 - loss: 0.5063 - val_accuracy: 0.7705 - val_loss: 0.4899
# Epoch 6/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 57s 227ms/step - accuracy: 0.7615 - loss: 0.4908 - val_accuracy: 0.6725 - val_loss: 0.6264
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 58s 230ms/step - accuracy: 0.7656 - loss: 0.4778 - val_accuracy: 0.7720 - val_loss: 0.4863
# Epoch 8/25
# ...

# %% [markdown]
# ### Step 5 - Prediction with a Single Image

# %% [markdown]
# In this step, we will attempt to perform a prediction on a single dog or cat image.

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('dataset/single_prediction/cat_or_dog_1.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
print("Prediction:", prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Prediction: dog
